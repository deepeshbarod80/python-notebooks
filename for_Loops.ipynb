# %% [markdown]
# <a href="https://colab.research.google.com/github/deepeshbarod80/python-notebooks/blob/main/for_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for number in range (3):
  print("Attempt", number)
# Out:
# Attempt 0
# Attempt 1
# Attempt 2

# %%
for number in range (3):
  print("Attempt", number + 1)
# Out:
# Attempt 1
# Attempt 2
# Attempt 3

# %%
for number in range (3):
  print("Attempt", number + 1, (number + 1) * '&')
# Out:
# Attempt 1 &
# Attempt 2 &&
# Attempt 3 &&&

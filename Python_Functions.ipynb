# %% [markdown]
# <a href="https://colab.research.google.com/github/deepeshbarod80/python-notebooks/blob/main/Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Functions in Python
# Purpose:
          # Perform a task
          # Return a value

# Creating a simple function.
def greet():
  print("Hi There")
  print("This is Deepesh")

greet()
# Out:
# Hi There
# This is Deepesh

# %%
def greet(first_name, last_name):
  print(f"Hi {first_name} {last_name}")
  print("Welcome to Abroad")

greet("Mosh", "Hamedani")
# Out:
# Hi Mosh Hamedani
# Welcome to Abroad
